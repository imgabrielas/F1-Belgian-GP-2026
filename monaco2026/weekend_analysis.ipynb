# %% [markdown]
# ### Quali

# %%
import pandas as pd

df = pd.read_csv('weekend_data/qualifying.csv')
df
# Out:
#     DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 0             12   K ANTONELLI          ANT       antonelli         Mercedes
# 1              3  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 2             44    L HAMILTON          HAM        hamilton          Ferrari
# 3             16     C LECLERC          LEC         leclerc          Ferrari
# 4              6      I HADJAR          HAD          hadjar  Red Bull Racing
# 5             63     G RUSSELL          RUS         russell         Mercedes
# 6             81     O PIASTRI          PIA         piastri          McLaren
# 7              1      L NORRIS          NOR          norris          McLaren
# 8             10       P GASLY          GAS           gasly           Alpine
# 9             30      L LAWSON          LAW          lawson     Racing Bulls
# 10            23       A ALBON          ALB           albon         Williams
# ...

# %%
df = df.drop(columns=['BroadcastName','DriverId','TeamColor','TeamId','FirstName','LastName','FullName','HeadshotUrl','CountryCode','ClassifiedPosition','GridPosition','Time','Status','Points','Laps'], errors='ignore')

df
# Out:
#     DriverNumber Abbreviation         TeamName  Position  \
# 0             12          ANT         Mercedes         1
# 1              3          VER  Red Bull Racing         2
# 2             44          HAM          Ferrari         3
# 3             16          LEC          Ferrari         4
# 4              6          HAD  Red Bull Racing         5
# 5             63          RUS         Mercedes         6
# 6             81          PIA          McLaren         7
# 7              1          NOR          McLaren         8
# 8             10          GAS           Alpine         9
# 9             30          LAW     Racing Bulls        10
# 10            23          ALB         Williams        11
# 11            55          SAI         Williams        12
# 12            27          HUL             Audi        13
# 13            43          COL           Alpine        14
# 14            41          LIN     Racing Bulls        15
# ...

# %%
q1_td = pd.to_timedelta(df['Q1'], errors='coerce')
top5 = df.loc[q1_td.nlargest(5).index]
print(f"Drivers who finished their qualifying on Q1: {', '.join(top5['Abbreviation'])}")

# %%
remaining_q1 = df.loc[df['Q2'].notna(), 'Abbreviation'].head(10)
print(", ".join(remaining_q1))

# %%
fastest_idx = q1_td.idxmin()
slowest_idx = q1_td.idxmax()

fastest_driver = df.loc[fastest_idx, 'Abbreviation']
slowest_driver = df.loc[slowest_idx, 'Abbreviation']
best_time = q1_td.min()
worst_time = q1_td.max()
gap = worst_time - best_time

print(f"Fastest Q1 time: {fastest_driver} - {best_time}")
print(f"Slowest Q1 time: {slowest_driver} - {worst_time}")
print(f"Gap between fastest and slowest: {gap.total_seconds():.3f} seconds")
print(f"On a track as tight as Monaco, a gap of {gap.total_seconds():.3f}s over a ~72s lap shows just how unforgiving the smallest mistake or setup compromise can be.")
